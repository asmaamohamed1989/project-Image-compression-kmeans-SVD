# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from PIL import Image
# The below two are visualization libraires
import matplotlib.pyplot as plt
import seaborn as sns 

# for calculating interval
from time import time

plt.rcParams['figure.figsize'] = 10,8 # setting default figure size for the kernel

# for clustering image pixels
from sklearn.cluster import KMeans 
# for simple image processing tasks
from skimage import io


#read image
# url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTzLzdD4MoAPP3I_JjrxndAqKg1zXtEnaODwsHbH6il9BL3Qt61'
# img_original = io.imread(url)
plt.axis('off')
#plt.imshow(img_original)
plt.title('Our buddy for the experiment !')
#plt.show()
img_original = Image.open('lena.png')
img = np.array(img_original,dtype=float) / 255

# Save the dimensions, we will be need them later
w, h, d = original_shape = img.shape
print('Original Shape'.center(20,'='))
print(img.shape)

# image_array size - w*h , d
image_array = img.reshape(-1,d)
print('ReShaped'.center(20,'='))
print(image_array.shape)

n_colours = [64,32]

# 64 colour image
t0 = time()

#Number of clusters n_clusters


kmeans64 = KMeans(n_clusters = n_colours[0],random_state=42,verbose=2,n_jobs=-1).fit(image_array)

print('Completed 64 clusters in'+ str({round(time()-t0,2)})+'seconds.')

# # 32 colour image
# t0 = time()
# kmeans32 = KMeans(n_clusters = n_colours[1],random_state=42,verbose=2,n_jobs=-1)
# kmeans32.fit(image_array)

# print('Completed 32 clusters in' + str({round(time()-t0,2)})+  ' seconds.')

labels64 = kmeans64.labels_
# labels32 = kmeans32.labels_


print('Within cluster sum of square error for'+str( {n_colours[0]})+' clusters = '+str({round(kmeans64.inertia_,2)}))
# print('Within cluster sum of square error for'+str( {n_colours[1]})+' clusters = '+str({round(kmeans32.inertia_,2)}))
# print('Within cluster sum of square error for {n_colours[1]} clusters = {round(kmeans32.inertia_,2)}')


def recreate_image(centroids, labels, w, h):
    # centroids variable are calculated from the flattened image
    # centroids: w*h, d 
    # so each row depicts the values per depth
    d = centroids.shape[1]
    print()
    image = np.zeros((w, h, d))
    label_idx = 0
    for i in range(w):
        for j in range(h):
            # filling values in new image with centroid values
            image[i][j] = centroids[labels[label_idx]]
            label_idx += 1
    return image


# plt.figure(figsize=(20,10))
# plt.subplot(132)
# plt.axis('off')
# plt.title('Original image')
#plt.imshow(img)

# plt.subplot(131)
# plt.axis('off')
# plt.title('Compressed image (64 colors, K-Means)')
comp_img64 = recreate_image(kmeans64.cluster_centers_, labels64, w, h)
print(comp_img64.shape)
#plt.imshow(comp_img64)

# plt.subplot(133)
# plt.axis('off')
# plt.title('Compressed image (32 colors, K-Means)')
# comp_img32 = recreate_image(kmeans32.cluster_centers_, labels32, w, h)
#plt.imshow(comp_img32)

#plt.show()

# Peak signal-to-noise ratio (PSNR) is the ratio between the maximum possible power
# of an image and the power of corrupting noise that affects the quality of its representation.
# Out:
# ===Original Shape===
# (512, 512, 3)
# ======ReShaped======
# (262144, 3)
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:938: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn("'n_jobs' was deprecated in version 0.23 and will be"
# Initialization complete
# Iteration 0, inertia 362.0478431372257
# Iteration 1, inertia 314.0617094467055
# Iteration 2, inertia 305.7355505747639
# Iteration 3, inertia 302.1412655724837
# Iteration 4, inertia 299.9894675565758
# Iteration 5, inertia 298.4856310303995
# Iteration 6, inertia 297.2250525354241
# Iteration 7, inertia 296.09251279127653
# Iteration 8, inertia 295.05482256364644
# Iteration 9, inertia 294.19456375753066
# Iteration 10, inertia 293.52536293732027
# Iteration 11, inertia 292.97771616002774
# Iteration 12, inertia 292.49464057596214
# Iteration 13, inertia 292.020026528173
# Iteration 14, inertia 291.58461321371766
# Iteration 15, inertia 291.14581403199
# Iteration 16, inertia 290.7485538023683
# Iteration 17, inertia 290.35604200871313
# Iteration 18, inertia 289.9460690664224
# Iteration 19, inertia 289.6657562911984
# Iteration 20, inertia 289.4474197446317
# Iteration 21, inertia 289.2887596188485
# Iteration 22, inertia 289.1813157240022
# Iteration 23, inertia 289.0867468920069
# Iteration 24, inertia 289.0057382888595
# Iteration 25, inertia 288.926984127623
# Iteration 26, inertia 288.8554874017057
# Iteration 27, inertia 288.7935986651673
# Iteration 28, inertia 288.73448097606763
# Iteration 29, inertia 288.68674634004054
# Iteration 30, inertia 288.6434953125158
# Iteration 31, inertia 288.6063181980351
# Iteration 32, inertia 288.56885705690246
# Iteration 33, inertia 288.5350602541532
# Iteration 34, inertia 288.4978964069889
# Iteration 35, inertia 288.4617848052762
# Iteration 36, inertia 288.42227929436694
# Iteration 37, inertia 288.3910855835021
# Iteration 38, inertia 288.36210024229075
# Iteration 39, inertia 288.3341856316504
# Iteration 40, inertia 288.31039251907623
# Iteration 41, inertia 288.28176275695466
# Iteration 42, inertia 288.25913686106014
# Converged at iteration 42: center shift 2.3070507960799304e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 364.21493271818247
# Iteration 1, inertia 312.4471564449233
# Iteration 2, inertia 304.31128317713285
# Iteration 3, inertia 300.9758726710987
# Iteration 4, inertia 298.8149624759505
# Iteration 5, inertia 297.09656174583756
# Iteration 6, inertia 295.7639063036606
# Iteration 7, inertia 294.64077645115725
# Iteration 8, inertia 293.6284802849247
# Iteration 9, inertia 292.77182215487244
# Iteration 10, inertia 292.10454086622445
# Iteration 11, inertia 291.5957028151815
# Iteration 12, inertia 291.2227143759918
# Iteration 13, inertia 290.94728725947874
# Iteration 14, inertia 290.7287809873442
# Iteration 15, inertia 290.5354585013536
# Iteration 16, inertia 290.3354972980763
# Iteration 17, inertia 290.1511505283474
# Iteration 18, inertia 289.98152069390886
# Iteration 19, inertia 289.82448312007534
# Iteration 20, inertia 289.68786704148965
# Iteration 21, inertia 289.5652316257313
# Iteration 22, inertia 289.43559215727714
# Iteration 23, inertia 289.317775001461
# Iteration 24, inertia 289.2056394172809
# Iteration 25, inertia 289.10007399134116
# Iteration 26, inertia 289.0108602869929
# Iteration 27, inertia 288.9208190959396
# Iteration 28, inertia 288.8459059653319
# Iteration 29, inertia 288.77747733193746
# Iteration 30, inertia 288.7152314563034
# Iteration 31, inertia 288.65665495887936
# Iteration 32, inertia 288.61236860761227
# Iteration 33, inertia 288.5759056335035
# Iteration 34, inertia 288.5428517670091
# Iteration 35, inertia 288.5120052252937
# Iteration 36, inertia 288.48681577725364
# Iteration 37, inertia 288.46375704356495
# Iteration 38, inertia 288.44302452439575
# Iteration 39, inertia 288.42481358159336
# Converged at iteration 39: center shift 2.823558588910518e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 373.97866974239906
# Iteration 1, inertia 321.84207487756726
# Iteration 2, inertia 310.67145864109153
# Iteration 3, inertia 305.7353519684066
# Iteration 4, inertia 303.096133343839
# Iteration 5, inertia 301.32310327979246
# Iteration 6, inertia 299.8642530822545
# Iteration 7, inertia 298.56286002869143
# Iteration 8, inertia 297.4473345549164
# Iteration 9, inertia 296.51455742150625
# Iteration 10, inertia 295.7423262023179
# Iteration 11, inertia 295.0307704150598
# Iteration 12, inertia 294.3470491339531
# Iteration 13, inertia 293.6925935379467
# Iteration 14, inertia 293.0874709320518
# Iteration 15, inertia 292.5434733711811
# Iteration 16, inertia 292.0601668656288
# Iteration 17, inertia 291.6504402712404
# Iteration 18, inertia 291.3219247774359
# Iteration 19, inertia 291.0692621406647
# Iteration 20, inertia 290.8654285635855
# Iteration 21, inertia 290.68583048825093
# Iteration 22, inertia 290.54096018179166
# Iteration 23, inertia 290.431436387073
# Iteration 24, inertia 290.3354682751671
# Iteration 25, inertia 290.25871786558116
# Iteration 26, inertia 290.18956367709035
# Iteration 27, inertia 290.1311113139601
# Iteration 28, inertia 290.0757327157392
# Iteration 29, inertia 290.02052787386674
# Iteration 30, inertia 289.963712462005
# Iteration 31, inertia 289.90465451063614
# Iteration 32, inertia 289.849617762545
# Iteration 33, inertia 289.7919992417459
# Iteration 34, inertia 289.7328006670757
# Iteration 35, inertia 289.6787447520515
# Iteration 36, inertia 289.6242381811807
# Iteration 37, inertia 289.5756458927547
# Iteration 38, inertia 289.5317913048561
# Iteration 39, inertia 289.4924655530422
# Iteration 40, inertia 289.45649671737687
# Iteration 41, inertia 289.42106253565316
# Iteration 42, inertia 289.3854742084797
# Iteration 43, inertia 289.3525329937642
# Iteration 44, inertia 289.32137180551035
# Iteration 45, inertia 289.2891157234912
# Iteration 46, inertia 289.258607735095
# Iteration 47, inertia 289.22967715203555
# Iteration 48, inertia 289.19877855415604
# Iteration 49, inertia 289.1658446273758
# Iteration 50, inertia 289.1310882494815
# Iteration 51, inertia 289.08609396619977
# Iteration 52, inertia 289.0348076511072
# Iteration 53, inertia 288.972071094824
# Iteration 54, inertia 288.91349494524655
# Iteration 55, inertia 288.8504123444227
# Iteration 56, inertia 288.784788681959
# Iteration 57, inertia 288.7253294233014
# Iteration 58, inertia 288.66410267300927
# Iteration 59, inertia 288.60373383653354
# Iteration 60, inertia 288.55018502084806
# Iteration 61, inertia 288.50167981447004
# Iteration 62, inertia 288.46238467263237
# Iteration 63, inertia 288.42961486410337
# Iteration 64, inertia 288.3947931932478
# Iteration 65, inertia 288.3625338576868
# Iteration 66, inertia 288.33241448366397
# Iteration 67, inertia 288.3082551759087
# Converged at iteration 67: center shift 3.226349462845367e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 362.28026143789646
# Iteration 1, inertia 310.959812094536
# Iteration 2, inertia 302.54706635546717
# Iteration 3, inertia 298.9049675675617
# Iteration 4, inertia 296.88279666836894
# Iteration 5, inertia 295.69259576707793
# Iteration 6, inertia 294.8855343086363
# Iteration 7, inertia 294.2975495915615
# Iteration 8, inertia 293.8065381938381
# Iteration 9, inertia 293.4073331335906
# Iteration 10, inertia 293.0507722808132
# Iteration 11, inertia 292.718026956294
# Iteration 12, inertia 292.4258075491916
# Iteration 13, inertia 292.19567560398355
# Iteration 14, inertia 292.01138302934066
# Iteration 15, inertia 291.85391095968566
# Iteration 16, inertia 291.72808128864745
# Iteration 17, inertia 291.61824247416314
# Iteration 18, inertia 291.51297391254064
# Iteration 19, inertia 291.4255370197744
# Iteration 20, inertia 291.3381625700385
# Iteration 21, inertia 291.26224014190615
# Iteration 22, inertia 291.1908187845584
# Iteration 23, inertia 291.12607869937835
# Iteration 24, inertia 291.05512740330124
# Iteration 25, inertia 290.98212986308437
# Iteration 26, inertia 290.9160461555637
# Iteration 27, inertia 290.84688080000495
# Iteration 28, inertia 290.7810633766266
# Iteration 29, inertia 290.7084661071122
# Iteration 30, inertia 290.60448127456937
# Iteration 31, inertia 290.4889134839352
# Iteration 32, inertia 290.38109533645735
# Iteration 33, inertia 290.2853011841159
# Iteration 34, inertia 290.18434746312334
# Iteration 35, inertia 290.08010400226516
# Iteration 36, inertia 289.98690462902715
# Iteration 37, inertia 289.90293409279184
# Iteration 38, inertia 289.8322271321751
# Iteration 39, inertia 289.7726594386488
# Iteration 40, inertia 289.7157036422006
# Iteration 41, inertia 289.67327489691075
# Iteration 42, inertia 289.6300902577907
# Iteration 43, inertia 289.58053471968435
# Iteration 44, inertia 289.5299070450103
# Iteration 45, inertia 289.4713491422599
# Iteration 46, inertia 289.40824107768185
# Iteration 47, inertia 289.3323848519112
# Iteration 48, inertia 289.23453768156446
# Iteration 49, inertia 289.1212527374362
# Iteration 50, inertia 289.00836507066225
# Iteration 51, inertia 288.8970934296102
# Iteration 52, inertia 288.8036871016982
# Iteration 53, inertia 288.72109769232947
# Iteration 54, inertia 288.6600333597598
# Iteration 55, inertia 288.5947453895039
# Iteration 56, inertia 288.53162934304527
# Iteration 57, inertia 288.4793222524711
# Iteration 58, inertia 288.43424827915254
# Iteration 59, inertia 288.39515044755285
# Iteration 60, inertia 288.36859249505665
# Iteration 61, inertia 288.3446966746205
# Converged at iteration 61: center shift 3.1841638594029643e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 363.95104959630703
# Iteration 1, inertia 316.91219383854036
# Iteration 2, inertia 307.85252294675485
# Iteration 3, inertia 303.6333097615139
# Iteration 4, inertia 300.8879763207282
# Iteration 5, inertia 298.71519019042057
# Iteration 6, inertia 296.94171965407935
# Iteration 7, inertia 295.5590057779039
# Iteration 8, inertia 294.55144122720213
# Iteration 9, inertia 293.78849117555666
# Iteration 10, inertia 293.19290079192916
# Iteration 11, inertia 292.67052135087243
# Iteration 12, inertia 292.209936125892
# Iteration 13, inertia 291.7983610880164
# Iteration 14, inertia 291.45121817195565
# Iteration 15, inertia 291.1652800876283
# Iteration 16, inertia 290.90985524950156
# Iteration 17, inertia 290.6840172820621
# Iteration 18, inertia 290.4895576792019
# Iteration 19, inertia 290.34550290557775
# Iteration 20, inertia 290.2226417500782
# Iteration 21, inertia 290.11515622779234
# Iteration 22, inertia 290.0235658252805
# Iteration 23, inertia 289.9512830130712
# Iteration 24, inertia 289.88240586983744
# Iteration 25, inertia 289.821281212699
# Iteration 26, inertia 289.7666498465332
# Iteration 27, inertia 289.7144583667855
# Iteration 28, inertia 289.6583159687063
# Iteration 29, inertia 289.5972758672393
# Iteration 30, inertia 289.53595088524264
# Iteration 31, inertia 289.4644203861192
# Iteration 32, inertia 289.3807541674123
# Iteration 33, inertia 289.27621169940403
# Iteration 34, inertia 289.1736059583999
# Iteration 35, inertia 289.070400857823
# Iteration 36, inertia 288.96632515594297
# Iteration 37, inertia 288.86469977640945
# Iteration 38, inertia 288.7805781760792
# Iteration 39, inertia 288.7080251833924
# Iteration 40, inertia 288.6386755987067
# Iteration 41, inertia 288.5772901804889
# Iteration 42, inertia 288.5221138878013
# Iteration 43, inertia 288.4753734021638
# Iteration 44, inertia 288.4380132345556
# Iteration 45, inertia 288.40555385932294
# Iteration 46, inertia 288.37805740528796
# Converged at iteration 46: center shift 2.850423306172092e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 366.99564782775406
# Iteration 1, inertia 312.93179792263567
# Iteration 2, inertia 304.15151494278547
# Iteration 3, inertia 300.19751141428856
# Iteration 4, inertia 297.777583072532
# Iteration 5, inertia 296.21409320589953
# Iteration 6, inertia 295.0843145025398
# Iteration 7, inertia 294.2322626126685
# Iteration 8, inertia 293.63135697558937
# Iteration 9, inertia 293.2217668405796
# Iteration 10, inertia 292.8806706469967
# Iteration 11, inertia 292.5451760489236
# Iteration 12, inertia 292.1719984517657
# Iteration 13, inertia 291.7527025754187
# Iteration 14, inertia 291.4040166875563
# Iteration 15, inertia 291.13470004249484
# Iteration 16, inertia 290.93649886304814
# Iteration 17, inertia 290.77210499928003
# Iteration 18, inertia 290.6244014104758
# Iteration 19, inertia 290.49326222835305
# Iteration 20, inertia 290.39394733798827
# Iteration 21, inertia 290.29879385919804
# Iteration 22, inertia 290.2059912877178
# Iteration 23, inertia 290.1268340935073
# Iteration 24, inertia 290.05050852158064
# Iteration 25, inertia 289.9735604802036
# Iteration 26, inertia 289.89538685368655
# Iteration 27, inertia 289.8260033034368
# Iteration 28, inertia 289.75997611654014
# Iteration 29, inertia 289.69927858570423
# Iteration 30, inertia 289.63360093231154
# Iteration 31, inertia 289.5653182939791
# Iteration 32, inertia 289.4911765196493
# Iteration 33, inertia 289.41568134466434
# Iteration 34, inertia 289.35706266302356
# Iteration 35, inertia 289.2989812346946
# Iteration 36, inertia 289.2505159969541
# Iteration 37, inertia 289.2071878574642
# Iteration 38, inertia 289.16657650842075
# Iteration 39, inertia 289.1318027748888
# Iteration 40, inertia 289.09561307024154
# Iteration 41, inertia 289.0578188369866
# Iteration 42, inertia 289.0270788864954
# Iteration 43, inertia 289.00243393117324
# Iteration 44, inertia 288.9782710717582
# Iteration 45, inertia 288.9485255150749
# Iteration 46, inertia 288.9236934767775
# Iteration 47, inertia 288.8970173205737
# Iteration 48, inertia 288.86957347080795
# Iteration 49, inertia 288.836438892958
# Iteration 50, inertia 288.79673161425563
# Iteration 51, inertia 288.7659840099343
# Iteration 52, inertia 288.7382263000921
# Iteration 53, inertia 288.7120987413889
# Iteration 54, inertia 288.68967619340253
# Iteration 55, inertia 288.66752797477153
# Iteration 56, inertia 288.64834880882063
# Iteration 57, inertia 288.6277975315533
# Iteration 58, inertia 288.60436849399605
# Iteration 59, inertia 288.5809956746275
# Iteration 60, inertia 288.55675585067775
# Iteration 61, inertia 288.53105928741655
# Iteration 62, inertia 288.5083930612908
# Iteration 63, inertia 288.49011657177374
# Converged at iteration 63: center shift 2.6650327376806667e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 358.77831603228714
# Iteration 1, inertia 309.8135369231335
# Iteration 2, inertia 302.7446688936158
# Iteration 3, inertia 300.0965556666433
# Iteration 4, inertia 298.5298232986711
# Iteration 5, inertia 297.45025164460253
# Iteration 6, inertia 296.6812296651307
# Iteration 7, inertia 296.10854005316054
# Iteration 8, inertia 295.6332312919295
# Iteration 9, inertia 295.243814257944
# Iteration 10, inertia 294.8703769466581
# Iteration 11, inertia 294.5182613617402
# Iteration 12, inertia 294.1752664796131
# Iteration 13, inertia 293.817484777702
# Iteration 14, inertia 293.4533457365051
# Iteration 15, inertia 293.05697315129464
# Iteration 16, inertia 292.6404658774838
# Iteration 17, inertia 292.1917362733581
# Iteration 18, inertia 291.75809880359355
# Iteration 19, inertia 291.32724111269613
# Iteration 20, inertia 290.92141904922624
# Iteration 21, inertia 290.5641029366963
# Iteration 22, inertia 290.24784761556083
# Iteration 23, inertia 289.9836225454941
# Iteration 24, inertia 289.7511455194577
# Iteration 25, inertia 289.54917039169436
# Iteration 26, inertia 289.3767182481041
# Iteration 27, inertia 289.2253623324173
# Iteration 28, inertia 289.09191242373754
# Iteration 29, inertia 288.9778384012445
# Iteration 30, inertia 288.87362891557075
# Iteration 31, inertia 288.77783986600014
# Iteration 32, inertia 288.68960281740726
# Iteration 33, inertia 288.600451564929
# Iteration 34, inertia 288.512625378264
# Iteration 35, inertia 288.4315572499502
# Iteration 36, inertia 288.36188744020336
# Iteration 37, inertia 288.29962381888237
# Iteration 38, inertia 288.2431768084597
# Iteration 39, inertia 288.18518678274523
# Iteration 40, inertia 288.13937246642354
# Iteration 41, inertia 288.101310022243
# Iteration 42, inertia 288.0718974983899
# Iteration 43, inertia 288.04620165567576
# Converged at iteration 43: center shift 2.8444574646780875e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 367.916555171093
# Iteration 1, inertia 317.328405310424
# Iteration 2, inertia 308.7247825918563
# Iteration 3, inertia 304.4094350976051
# Iteration 4, inertia 301.799159989871
# Iteration 5, inertia 300.0713756501276
# Iteration 6, inertia 298.854139977994
# Iteration 7, inertia 297.89648540575604
# Iteration 8, inertia 297.0675445702084
# Iteration 9, inertia 296.2996723683773
# Iteration 10, inertia 295.67185277516944
# Iteration 11, inertia 295.1690913264981
# Iteration 12, inertia 294.7262605133515
# Iteration 13, inertia 294.29305135394435
# Iteration 14, inertia 293.86675696486884
# Iteration 15, inertia 293.39774200767573
# Iteration 16, inertia 292.9291035347375
# Iteration 17, inertia 292.5194569537764
# Iteration 18, inertia 292.168828737528
# Iteration 19, inertia 291.87123032452166
# Iteration 20, inertia 291.6277666534828
# Iteration 21, inertia 291.4316395461825
# Iteration 22, inertia 291.2629719457706
# Iteration 23, inertia 291.12416832910145
# Iteration 24, inertia 291.01732245630893
# Iteration 25, inertia 290.92340561122137
# Iteration 26, inertia 290.8365164440797
# Iteration 27, inertia 290.75607799100186
# Iteration 28, inertia 290.6824992422468
# Iteration 29, inertia 290.6123948155888
# Iteration 30, inertia 290.5418947325606
# Iteration 31, inertia 290.47040410435693
# Iteration 32, inertia 290.3952686212685
# Iteration 33, inertia 290.31790858503723
# Iteration 34, inertia 290.24197620154854
# Iteration 35, inertia 290.1632915437996
# Iteration 36, inertia 290.08834485600977
# Iteration 37, inertia 290.0127707745645
# Iteration 38, inertia 289.943778509791
# Iteration 39, inertia 289.8844832598321
# Iteration 40, inertia 289.82782233348775
# Iteration 41, inertia 289.7795264544146
# Iteration 42, inertia 289.7432612517265
# Iteration 43, inertia 289.71465748679856
# Iteration 44, inertia 289.68489251858034
# Iteration 45, inertia 289.65857317768297
# Iteration 46, inertia 289.6318954274673
# Iteration 47, inertia 289.60333698715834
# Iteration 48, inertia 289.57235621596175
# Iteration 49, inertia 289.5416455357152
# Iteration 50, inertia 289.5127449358239
# Iteration 51, inertia 289.4780073590277
# Iteration 52, inertia 289.4412628560431
# Iteration 53, inertia 289.404853385478
# Iteration 54, inertia 289.36664748081375
# Iteration 55, inertia 289.3301265679493
# Iteration 56, inertia 289.2890038875365
# Iteration 57, inertia 289.2518504295094
# Iteration 58, inertia 289.2168766601928
# Iteration 59, inertia 289.1816060317893
# Iteration 60, inertia 289.1471454842517
# Iteration 61, inertia 289.120008205091
# Iteration 62, inertia 289.0957808641147
# Converged at iteration 62: center shift 2.8321129889404595e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 370.5751480199852
# Iteration 1, inertia 316.0753918028422
# Iteration 2, inertia 307.08857500987784
# Iteration 3, inertia 303.01263009440396
# Iteration 4, inertia 300.5146131095569
# Iteration 5, inertia 298.72363419360335
# Iteration 6, inertia 297.3535546413575
# Iteration 7, inertia 296.28498922664164
# Iteration 8, inertia 295.39808428153566
# Iteration 9, inertia 294.68661867270214
# Iteration 10, inertia 294.0635346340988
# Iteration 11, inertia 293.5321216059131
# Iteration 12, inertia 293.04063167978154
# Iteration 13, inertia 292.6413536719181
# Iteration 14, inertia 292.3239074818112
# Iteration 15, inertia 292.04407235278336
# Iteration 16, inertia 291.8072102459334
# Iteration 17, inertia 291.6059607347596
# Iteration 18, inertia 291.43151803960063
# Iteration 19, inertia 291.27834797401874
# Iteration 20, inertia 291.13081937939586
# Iteration 21, inertia 290.9860225311683
# Iteration 22, inertia 290.84812073947074
# Iteration 23, inertia 290.6947835082222
# Iteration 24, inertia 290.5172348608694
# Iteration 25, inertia 290.3374573365883
# Iteration 26, inertia 290.16401034292636
# Iteration 27, inertia 289.99877171360777
# Iteration 28, inertia 289.8569819516947
# Iteration 29, inertia 289.7290513043046
# Iteration 30, inertia 289.6138678192474
# Iteration 31, inertia 289.5167700679321
# Iteration 32, inertia 289.431035233312
# Iteration 33, inertia 289.34228584481366
# Iteration 34, inertia 289.2557357470287
# Iteration 35, inertia 289.1766860105111
# Iteration 36, inertia 289.0975660657413
# Iteration 37, inertia 289.0280587117513
# Iteration 38, inertia 288.9647499832782
# Iteration 39, inertia 288.9099927862323
# Iteration 40, inertia 288.8591608405237
# Iteration 41, inertia 288.81718481532647
# Iteration 42, inertia 288.7757425530451
# Iteration 43, inertia 288.74218162428673
# Iteration 44, inertia 288.7095229092669
# Iteration 45, inertia 288.6789836407848
# Iteration 46, inertia 288.6538075462727
# Converged at iteration 46: center shift 2.816247222013992e-06 within tolerance 3.261184843897328e-06.
# Initialization complete
# Iteration 0, inertia 361.9045905420782
# Iteration 1, inertia 312.1523747597303
# Iteration 2, inertia 303.0293974184124
# Iteration 3, inertia 299.18227284003893
# Iteration 4, inertia 297.1492690113892
# Iteration 5, inertia 295.76975573004034
# Iteration 6, inertia 294.6988380547655
# Iteration 7, inertia 293.82268072391355
# Iteration 8, inertia 293.12886098216524
# Iteration 9, inertia 292.55983027817996
# Iteration 10, inertia 292.05858248153726
# Iteration 11, inertia 291.6453751193393
# Iteration 12, inertia 291.2750683678062
# Iteration 13, inertia 290.9539902411981
# Iteration 14, inertia 290.6705847847614
# Iteration 15, inertia 290.3863856360229
# Iteration 16, inertia 290.12550796375945
# Iteration 17, inertia 289.87290954155054
# Iteration 18, inertia 289.645670128721
# Iteration 19, inertia 289.4564932081135
# Iteration 20, inertia 289.2906764626143
# Iteration 21, inertia 289.1536623727207
# Iteration 22, inertia 289.03962798586997
# Iteration 23, inertia 288.94272149949063
# Iteration 24, inertia 288.8591595153429
# Iteration 25, inertia 288.78818302621437
# Iteration 26, inertia 288.7323412603
# Iteration 27, inertia 288.6790036025067
# Iteration 28, inertia 288.63263570109723
# Iteration 29, inertia 288.59090300239916
# Iteration 30, inertia 288.5499699359801
# Iteration 31, inertia 288.5175169995373
# Iteration 32, inertia 288.49017841262116
# Iteration 33, inertia 288.4678412784537
# Iteration 34, inertia 288.44723693793316
# Converged at iteration 34: center shift 2.972823264776738e-06 within tolerance 3.261184843897328e-06.
# Completed 64 clusters in{65.84}seconds.
# Within cluster sum of square error for{64} clusters = {288.05}
# (512, 512, 3)

# %%
import numpy as np
from sewar import full_ref
from skimage import measure
import math


ref_img = comp_img64


original_size = w*h*24
#Compressed image needs 24K+Nlog2K bits 
compressedSize64 = w*h*math.log2(n_colours[1])

print("compression ratio(CR) of k-means 64 colors = "+str(int((compressedSize64/original_size)*100))+"%")
##############################################################
mse_skimg = measure.compare_mse(ref_img, img)
print("MSE: based on scikit-image = ", mse_skimg)

#Same as PSNR available in sewar
psnr_skimg = measure.compare_psnr(ref_img, img, data_range=None)
print("PSNR: based on scikit-image = ", psnr_skimg)

# #Normalized root mean squared error
# rmse_skimg = measure.compare_nrmse(ref_img, img)
# print("RMSE: based on scikit-image = ", rmse_skimg)


###############################################################
#ERGAS Global relative error
"""calculates global relative error 
GT: first (original) input image.
P: second (deformed) input image.
r: ratio of high resolution to low resolution (default=4).
ws: sliding window size (default = 8).
	:returns:  float -- ergas value.
	"""
ergas_img = full_ref.ergas(ref_img, img, r=4, ws=8)
print("EGRAS: global relative error = ", ergas_img)

#######################################################################
#relative average spectral error (rase)
"""calculates relative average spectral error (rase).
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:param ws: sliding window size (default = 8).
	:returns:  float -- rase value.
	"""
RASE_img = full_ref.rase(ref_img, img, ws=8)
print("RASE: relative average spectral error = ", RASE_img)


######################################################################
#RMSE
"""calculates root mean squared error (rmse).
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:returns:  float -- rmse value.
	"""
rmse_img = full_ref.rmse(ref_img, img)
print("RMSE: root mean squared error = ", rmse_img)



######################################################################
#root mean squared error (rmse) using sliding window
"""calculates root mean squared error (rmse) using sliding window.
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:param ws: sliding window size (default = 8).
	:returns:  tuple -- rmse value,rmse map.	
	"""
# rmse_sw_img = full_ref.rmse_sw(ref_img, img, ws=8)
# print("RMSE_SW: root mean squared error with sliding window = ", rmse_sw_img)


#########################################################################
#calculates spectral angle mapper (sam).
"""calculates spectral angle mapper (sam).
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:returns:  float -- sam value.
	"""
ref_sam_img = full_ref.sam(ref_img, img)
print("REF_SAM: spectral angle mapper = ", ref_sam_img)



##############################################################################
#Universal image quality index
"""calculates universal image quality index (uqi).
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:param ws: sliding window size (default = 8).
	:returns:  float -- uqi value.
	"""
UQI_img = full_ref.uqi(ref_img, img, ws=8)
print("UQI: universal image quality index = ", UQI_img)

##############################################################################
#Pixel Based Visual Information Fidelity (vif-p)
"""calculates Pixel Based Visual Information Fidelity (vif-p).
	:param GT: first (original) input image.
	:param P: second (deformed) input image.
	:param sigma_nsq: variance of the visual noise (default = 2)
	:returns:  float -- vif-p value.
	"""
VIFP_img = full_ref.vifp(ref_img, img, sigma_nsq=2)
print("VIFP: Pixel Based Visual Information Fidelity = ", VIFP_img)
# Out:
# compression ratio(CR) of k-means 64 colors = 20%
# MSE: based on scikit-image =  0.00036626968594318074
# PSNR: based on scikit-image =  34.361990239300255
# EGRAS: global relative error =  1837.2406802748087
# RASE: relative average spectral error =  264.96743845234096
# RMSE: root mean squared error =  0.01913817352683324
# <ipython-input-7-b72a473a1139>:16: UserWarning: DEPRECATED: skimage.measure.compare_mse has been moved to skimage.metrics.mean_squared_error. It will be removed from skimage.measure in version 0.18.
#   mse_skimg = measure.compare_mse(ref_img, img)
# <ipython-input-7-b72a473a1139>:20: UserWarning: DEPRECATED: skimage.measure.compare_psnr has been moved to skimage.metrics.peak_signal_noise_ratio. It will be removed from skimage.measure in version 0.18.
#   psnr_skimg = measure.compare_psnr(ref_img, img, data_range=None)
# REF_SAM: spectral angle mapper =  0.03797083500339796
# UQI: universal image quality index =  0.998353143100689
# VIFP: Pixel Based Visual Information Fidelity =  0.9608910091359905
